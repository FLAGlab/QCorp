# %%
class Gridworld:
    def __init__(self):
        self.board = [[0]*10 for i in range(10)]
        self.board[5][5] = True
    
    def start(self):
        return (0, 0)
    
    def trap(self):
        return[(4,5), (7,5), (7,6)]
    
    def end(self): 
        return (5, 5)

# %%
import numpy as np
import random
class Learner:
    def __init__(self, agent, env, alpha=0.1, gamma=0.6, epsilon=0.1):
        #hyper parameters
        self.alpha = alpha
        self.gamma = gamma
        self.epsilon = epsilon
        self.environment = env
        self.agent = agent          #actual agent
        self.qtable = self.__initdic__() #rewards table
    
    def __initdic__(self):
        table = dict()
        n = len(self.environment.board)
        for i in range(n):
            for j in range(n):
                table[(i,j)] = np.zeros(len(self.agent.actions))
        return table

    def run(self):
        done = False
        while not done:
            current_state = self.agent.state
            if random.uniform(0,1) < self.epsilon:
                action = self.randomAction()
            else:
                action = np.argmax(self.qtable[current_state]) 
            next_state, reward, done, info = self.step(action)
            old_value = self.qtable[current_state][action]
            next_max = np.max(self.qtable[next_state])
            new_value = (1 - self.alpha)*old_value + self.alpha*(reward + self.gamma*next_max)
            self.qtable[current_state][action] = new_value

            print(info) # Descomentar para imprimir accion y estado
            print(f'{current_state}, {action}, {next_state}')

    def randomAction(self):
        # return random.randint(0,len(self.agent.actions)-1)
        return np.random.choice(self.agent.get_posible_actions())

    def step(self, action):
        old_state = self.agent.state
        reward, done = self.getRewards(old_state, self.agent.getAction(action))
        self.agent.action(action)
        next_state = self.agent.state
        info = f'Executed action: {self.agent.getAction(action)} at state {old_state}'
        return next_state, reward, done, info

    def getRewards(self, state, action):
        i,j =state
        if state == self.environment.end(): # hay dos manera de llegar arriba (Up) e izquierda(back).
            return 1, True
        elif (i,j) in self.environment.trap():
            return -1, True
        else: 
            return 0, False

# %%
import random

class Agent:
    def __init__(self, env):
        self.state = env.start()
        self.initial_state = env.start()
        self.actions = [0,1,2,3]  #0-izq, 1-der, 2-arriba, 3-abajo
        self.bound = len(env.board) - 1   
        self.blocked_states = [(2, i) for i in range(1, 5)]
        self.blocked_states += [(2, i) for i in range(6, 9)]
        self.blocked_states += [(i, 4) for i in range(2, 8)]
        
        
    def get_posible_actions(self):
        actions = []
        current_state = self.state
        for i in range(len(self.actions)):
            self.action(i)
            if current_state != self.state:
                actions.append(i)
                self.state = current_state
        #print(actions) #descomentar para imprimir acción
        return actions
        

    def forward(self): # derecha
        new_state = (self.state[0], min(self.state[1] + 1, self.bound))
        if new_state not in self.blocked_states:
            self.state = new_state
        
    def back(self): #izquierda
        new_state = (self.state[0], max(self.state[1] - 1, 0))
        if new_state not in self.blocked_states:
            self.state = new_state
        
    def upward(self): # arriba
        new_state = (max(self.state[0] - 1, 0), self.state[1])
        if new_state not in self.blocked_states:
            self.state = new_state
        
    def downward(self): # abajo
        new_state = (min(self.state[0] + 1, self.bound), self.state[1])
        if new_state not in self.blocked_states:
            self.state = new_state
        
    def action(self, action : int):
        if action == 1:
            self.forward()
        elif action == 0:
            self.back()
        elif action == 2:
            self.upward()
        else:
            self.downward()
            
    def reset(self):
        self.state = self.initial_state
    
    def getAction(self, action : int):
        if action == 1:
            return 'right'
        elif action == 0:
            return 'left'
        elif action == 2:
            return 'up'
        else:
            return 'down'

# %%
def main():
    episodes = 2
    e = Gridworld()
    a = Agent(e)
    l = Learner(a, e, epsilon=0.5)
    for i in range(0, episodes):
        print(f"Episode: {i+1}") # descomentar si se quiere imprimir el episodio
        l.run()
        a.reset()
    print(l.qtable)
        
main()
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Executed action: right at state (5, 0)
# (5, 0), 1, (5, 1)
# Executed action: down at state (5, 1)
# (5, 1), 3, (6, 1)
# Executed action: left at state (6, 1)
# (6, 1), 0, (6, 0)
# Executed action: right at state (6, 0)
# (6, 0), 1, (6, 1)
# Executed action: left at state (6, 1)
# (6, 1), 0, (6, 0)
# Executed action: left at state (6, 0)
# (6, 0), 0, (6, 0)
# Executed action: left at state (6, 0)
# (6, 0), 0, (6, 0)
# Executed action: left at state (6, 0)
# (6, 0), 0, (6, 0)
# Executed action: left at state (6, 0)
# (6, 0), 0, (6, 0)
# Executed action: left at state (6, 0)
# (6, 0), 0, (6, 0)
# Executed action: left at state (6, 0)
# (6, 0), 0, (6, 0)
# Executed action: left at state (6, 0)
# (6, 0), 0, (6, 0)
# Executed action: right at state (6, 0)
# (6, 0), 1, (6, 1)
# Executed action: left at state (6, 1)
# (6, 1), 0, (6, 0)
# Executed action: right at state (6, 0)
# (6, 0), 1, (6, 1)
# Executed action: left at state (6, 1)
# (6, 1), 0, (6, 0)
# Executed action: up at state (6, 0)
# (6, 0), 2, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: right at state (5, 0)
# (5, 0), 1, (5, 1)
# Executed action: up at state (5, 1)
# (5, 1), 2, (4, 1)
# Executed action: up at state (4, 1)
# (4, 1), 2, (3, 1)
# Executed action: left at state (3, 1)
# (3, 1), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: right at state (3, 0)
# (3, 0), 1, (3, 1)
# Executed action: left at state (3, 1)
# (3, 1), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: right at state (3, 0)
# (3, 0), 1, (3, 1)
# Executed action: left at state (3, 1)
# (3, 1), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: up at state (3, 0)
# (3, 0), 2, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: up at state (2, 0)
# (2, 0), 2, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: up at state (1, 0)
# (1, 0), 2, (0, 0)
# Executed action: left at state (0, 0)
# (0, 0), 0, (0, 0)
# Executed action: right at state (0, 0)
# (0, 0), 1, (0, 1)
# Executed action: left at state (0, 1)
# (0, 1), 0, (0, 0)
# Executed action: left at state (0, 0)
# (0, 0), 0, (0, 0)
# Executed action: left at state (0, 0)
# (0, 0), 0, (0, 0)
# Executed action: left at state (0, 0)
# (0, 0), 0, (0, 0)
# Executed action: down at state (0, 0)
# (0, 0), 3, (1, 0)
# Executed action: down at state (1, 0)
# (1, 0), 3, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: up at state (2, 0)
# (2, 0), 2, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: down at state (1, 0)
# (1, 0), 3, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: up at state (2, 0)
# (2, 0), 2, (1, 0)
# Executed action: up at state (1, 0)
# (1, 0), 2, (0, 0)
# Executed action: left at state (0, 0)
# (0, 0), 0, (0, 0)
# Executed action: left at state (0, 0)
# (0, 0), 0, (0, 0)
# Executed action: right at state (0, 0)
# (0, 0), 1, (0, 1)
# Executed action: right at state (0, 1)
# (0, 1), 1, (0, 2)
# Executed action: left at state (0, 2)
# (0, 2), 0, (0, 1)
# Executed action: left at state (0, 1)
# (0, 1), 0, (0, 0)
# Executed action: left at state (0, 0)
# (0, 0), 0, (0, 0)
# Executed action: left at state (0, 0)
# (0, 0), 0, (0, 0)
# Executed action: left at state (0, 0)
# (0, 0), 0, (0, 0)
# Executed action: right at state (0, 0)
# (0, 0), 1, (0, 1)
# Executed action: right at state (0, 1)
# (0, 1), 1, (0, 2)
# Executed action: left at state (0, 2)
# (0, 2), 0, (0, 1)
# Executed action: left at state (0, 1)
# (0, 1), 0, (0, 0)
# Executed action: left at state (0, 0)
# (0, 0), 0, (0, 0)
# Executed action: left at state (0, 0)
# (0, 0), 0, (0, 0)
# Executed action: left at state (0, 0)
# (0, 0), 0, (0, 0)
# Executed action: left at state (0, 0)
# (0, 0), 0, (0, 0)
# Executed action: right at state (0, 0)
# (0, 0), 1, (0, 1)
# Executed action: left at state (0, 1)
# (0, 1), 0, (0, 0)
# Executed action: down at state (0, 0)
# (0, 0), 3, (1, 0)
# Executed action: up at state (1, 0)
# (1, 0), 2, (0, 0)
# Executed action: down at state (0, 0)
# (0, 0), 3, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: down at state (1, 0)
# (1, 0), 3, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: up at state (2, 0)
# (2, 0), 2, (1, 0)
# Executed action: right at state (1, 0)
# (1, 0), 1, (1, 1)
# Executed action: left at state (1, 1)
# (1, 1), 0, (1, 0)
# Executed action: down at state (1, 0)
# (1, 0), 3, (2, 0)
# Executed action: down at state (2, 0)
# (2, 0), 3, (3, 0)
# Executed action: right at state (3, 0)
# (3, 0), 1, (3, 1)
# Executed action: left at state (3, 1)
# (3, 1), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: right at state (3, 0)
# (3, 0), 1, (3, 1)
# Executed action: down at state (3, 1)
# (3, 1), 3, (4, 1)
# Executed action: up at state (4, 1)
# (4, 1), 2, (3, 1)
# Executed action: left at state (3, 1)
# (3, 1), 0, (3, 0)
# Executed action: down at state (3, 0)
# (3, 0), 3, (4, 0)
# Executed action: down at state (4, 0)
# (4, 0), 3, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: down at state (5, 0)
# (5, 0), 3, (6, 0)
# Executed action: left at state (6, 0)
# (6, 0), 0, (6, 0)
# Executed action: up at state (6, 0)
# (6, 0), 2, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: right at state (5, 0)
# (5, 0), 1, (5, 1)
# Executed action: right at state (5, 1)
# (5, 1), 1, (5, 2)
# Executed action: up at state (5, 2)
# (5, 2), 2, (4, 2)
# Executed action: left at state (4, 2)
# (4, 2), 0, (4, 1)
# Executed action: left at state (4, 1)
# (4, 1), 0, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: down at state (4, 0)
# (4, 0), 3, (5, 0)
# Executed action: right at state (5, 0)
# (5, 0), 1, (5, 1)
# Executed action: left at state (5, 1)
# (5, 1), 0, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: right at state (5, 0)
# (5, 0), 1, (5, 1)
# Executed action: right at state (5, 1)
# (5, 1), 1, (5, 2)
# Executed action: left at state (5, 2)
# (5, 2), 0, (5, 1)
# Executed action: up at state (5, 1)
# (5, 1), 2, (4, 1)
# Executed action: left at state (4, 1)
# (4, 1), 0, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: up at state (4, 0)
# (4, 0), 2, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: right at state (3, 0)
# (3, 0), 1, (3, 1)
# Executed action: right at state (3, 1)
# (3, 1), 1, (3, 2)
# Executed action: left at state (3, 2)
# (3, 2), 0, (3, 1)
# Executed action: right at state (3, 1)
# (3, 1), 1, (3, 2)
# Executed action: left at state (3, 2)
# (3, 2), 0, (3, 1)
# Executed action: left at state (3, 1)
# (3, 1), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: right at state (3, 0)
# (3, 0), 1, (3, 1)
# Executed action: right at state (3, 1)
# (3, 1), 1, (3, 2)
# Executed action: left at state (3, 2)
# (3, 2), 0, (3, 1)
# Executed action: left at state (3, 1)
# (3, 1), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: up at state (3, 0)
# (3, 0), 2, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: up at state (2, 0)
# (2, 0), 2, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: up at state (1, 0)
# (1, 0), 2, (0, 0)
# Executed action: right at state (0, 0)
# (0, 0), 1, (0, 1)
# Executed action: down at state (0, 1)
# (0, 1), 3, (1, 1)
# Executed action: left at state (1, 1)
# (1, 1), 0, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: up at state (1, 0)
# (1, 0), 2, (0, 0)
# Executed action: left at state (0, 0)
# (0, 0), 0, (0, 0)
# Executed action: left at state (0, 0)
# (0, 0), 0, (0, 0)
# Executed action: right at state (0, 0)
# (0, 0), 1, (0, 1)
# Executed action: down at state (0, 1)
# (0, 1), 3, (1, 1)
# Executed action: left at state (1, 1)
# (1, 1), 0, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: right at state (1, 0)
# (1, 0), 1, (1, 1)
# Executed action: left at state (1, 1)
# (1, 1), 0, (1, 0)
# Executed action: up at state (1, 0)
# (1, 0), 2, (0, 0)
# Executed action: left at state (0, 0)
# (0, 0), 0, (0, 0)
# Executed action: right at state (0, 0)
# (0, 0), 1, (0, 1)
# Executed action: left at state (0, 1)
# (0, 1), 0, (0, 0)
# Executed action: left at state (0, 0)
# (0, 0), 0, (0, 0)
# Executed action: down at state (0, 0)
# (0, 0), 3, (1, 0)
# Executed action: down at state (1, 0)
# (1, 0), 3, (2, 0)
# Executed action: down at state (2, 0)
# (2, 0), 3, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: right at state (3, 0)
# (3, 0), 1, (3, 1)
# Executed action: down at state (3, 1)
# (3, 1), 3, (4, 1)
# Executed action: left at state (4, 1)
# (4, 1), 0, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: up at state (4, 0)
# (4, 0), 2, (3, 0)
# Executed action: down at state (3, 0)
# (3, 0), 3, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: right at state (4, 0)
# (4, 0), 1, (4, 1)
# Executed action: left at state (4, 1)
# (4, 1), 0, (4, 0)
# Executed action: down at state (4, 0)
# (4, 0), 3, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: right at state (5, 0)
# (5, 0), 1, (5, 1)
# Executed action: left at state (5, 1)
# (5, 1), 0, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: right at state (5, 0)
# (5, 0), 1, (5, 1)
# Executed action: right at state (5, 1)
# (5, 1), 1, (5, 2)
# Executed action: left at state (5, 2)
# (5, 2), 0, (5, 1)
# Executed action: left at state (5, 1)
# (5, 1), 0, (5, 0)
# Executed action: right at state (5, 0)
# (5, 0), 1, (5, 1)
# Executed action: left at state (5, 1)
# (5, 1), 0, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: up at state (5, 0)
# (5, 0), 2, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: right at state (4, 0)
# (4, 0), 1, (4, 1)
# Executed action: left at state (4, 1)
# (4, 1), 0, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: right at state (4, 0)
# (4, 0), 1, (4, 1)
# Executed action: left at state (4, 1)
# (4, 1), 0, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: right at state (4, 0)
# (4, 0), 1, (4, 1)
# Executed action: left at state (4, 1)
# (4, 1), 0, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: up at state (4, 0)
# (4, 0), 2, (3, 0)
# Executed action: right at state (3, 0)
# (3, 0), 1, (3, 1)
# Executed action: right at state (3, 1)
# (3, 1), 1, (3, 2)
# Executed action: left at state (3, 2)
# (3, 2), 0, (3, 1)
# Executed action: left at state (3, 1)
# (3, 1), 0, (3, 0)
# Executed action: up at state (3, 0)
# (3, 0), 2, (2, 0)
# Executed action: down at state (2, 0)
# (2, 0), 3, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: up at state (3, 0)
# (3, 0), 2, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: up at state (2, 0)
# (2, 0), 2, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: down at state (1, 0)
# (1, 0), 3, (2, 0)
# Executed action: up at state (2, 0)
# (2, 0), 2, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: right at state (1, 0)
# (1, 0), 1, (1, 1)
# Executed action: right at state (1, 1)
# (1, 1), 1, (1, 2)
# Executed action: right at state (1, 2)
# (1, 2), 1, (1, 3)
# Executed action: left at state (1, 3)
# (1, 3), 0, (1, 2)
# Executed action: left at state (1, 2)
# (1, 2), 0, (1, 1)
# Executed action: up at state (1, 1)
# (1, 1), 2, (0, 1)
# Executed action: down at state (0, 1)
# (0, 1), 3, (1, 1)
# Executed action: left at state (1, 1)
# (1, 1), 0, (1, 0)
# Executed action: right at state (1, 0)
# (1, 0), 1, (1, 1)
# Executed action: up at state (1, 1)
# (1, 1), 2, (0, 1)
# Executed action: left at state (0, 1)
# (0, 1), 0, (0, 0)
# Executed action: down at state (0, 0)
# (0, 0), 3, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: right at state (1, 0)
# (1, 0), 1, (1, 1)
# Executed action: left at state (1, 1)
# (1, 1), 0, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: down at state (1, 0)
# (1, 0), 3, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: down at state (2, 0)
# (2, 0), 3, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: down at state (3, 0)
# (3, 0), 3, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: down at state (4, 0)
# (4, 0), 3, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: up at state (5, 0)
# (5, 0), 2, (4, 0)
# Executed action: up at state (4, 0)
# (4, 0), 2, (3, 0)
# Executed action: up at state (3, 0)
# (3, 0), 2, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: down at state (2, 0)
# (2, 0), 3, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: right at state (3, 0)
# (3, 0), 1, (3, 1)
# Executed action: right at state (3, 1)
# (3, 1), 1, (3, 2)
# Executed action: left at state (3, 2)
# (3, 2), 0, (3, 1)
# Executed action: down at state (3, 1)
# (3, 1), 3, (4, 1)
# Executed action: down at state (4, 1)
# (4, 1), 3, (5, 1)
# Executed action: left at state (5, 1)
# (5, 1), 0, (5, 0)
# Executed action: down at state (5, 0)
# (5, 0), 3, (6, 0)
# Executed action: right at state (6, 0)
# (6, 0), 1, (6, 1)
# Executed action: left at state (6, 1)
# (6, 1), 0, (6, 0)
# Executed action: left at state (6, 0)
# (6, 0), 0, (6, 0)
# Executed action: up at state (6, 0)
# (6, 0), 2, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: up at state (5, 0)
# (5, 0), 2, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: up at state (4, 0)
# (4, 0), 2, (3, 0)
# Executed action: right at state (3, 0)
# (3, 0), 1, (3, 1)
# Executed action: left at state (3, 1)
# (3, 1), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: down at state (3, 0)
# (3, 0), 3, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: up at state (4, 0)
# (4, 0), 2, (3, 0)
# Executed action: down at state (3, 0)
# (3, 0), 3, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: up at state (4, 0)
# (4, 0), 2, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: up at state (3, 0)
# (3, 0), 2, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: up at state (2, 0)
# (2, 0), 2, (1, 0)
# Executed action: up at state (1, 0)
# (1, 0), 2, (0, 0)
# Executed action: left at state (0, 0)
# (0, 0), 0, (0, 0)
# Executed action: left at state (0, 0)
# (0, 0), 0, (0, 0)
# Executed action: down at state (0, 0)
# (0, 0), 3, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: up at state (1, 0)
# (1, 0), 2, (0, 0)
# Executed action: right at state (0, 0)
# (0, 0), 1, (0, 1)
# Executed action: down at state (0, 1)
# (0, 1), 3, (1, 1)
# Executed action: left at state (1, 1)
# (1, 1), 0, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: up at state (1, 0)
# (1, 0), 2, (0, 0)
# Executed action: left at state (0, 0)
# (0, 0), 0, (0, 0)
# Executed action: left at state (0, 0)
# (0, 0), 0, (0, 0)
# Executed action: left at state (0, 0)
# (0, 0), 0, (0, 0)
# Executed action: down at state (0, 0)
# (0, 0), 3, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: right at state (1, 0)
# (1, 0), 1, (1, 1)
# Executed action: left at state (1, 1)
# (1, 1), 0, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: up at state (1, 0)
# (1, 0), 2, (0, 0)
# Executed action: left at state (0, 0)
# (0, 0), 0, (0, 0)
# Executed action: down at state (0, 0)
# (0, 0), 3, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: right at state (1, 0)
# (1, 0), 1, (1, 1)
# Executed action: up at state (1, 1)
# (1, 1), 2, (0, 1)
# Executed action: left at state (0, 1)
# (0, 1), 0, (0, 0)
# Executed action: right at state (0, 0)
# (0, 0), 1, (0, 1)
# Executed action: left at state (0, 1)
# (0, 1), 0, (0, 0)
# Executed action: left at state (0, 0)
# (0, 0), 0, (0, 0)
# Executed action: left at state (0, 0)
# (0, 0), 0, (0, 0)
# Executed action: down at state (0, 0)
# (0, 0), 3, (1, 0)
# Executed action: down at state (1, 0)
# (1, 0), 3, (2, 0)
# Executed action: up at state (2, 0)
# (2, 0), 2, (1, 0)
# Executed action: right at state (1, 0)
# (1, 0), 1, (1, 1)
# Executed action: right at state (1, 1)
# (1, 1), 1, (1, 2)
# Executed action: right at state (1, 2)
# (1, 2), 1, (1, 3)
# Executed action: right at state (1, 3)
# (1, 3), 1, (1, 4)
# Executed action: up at state (1, 4)
# (1, 4), 2, (0, 4)
# Executed action: right at state (0, 4)
# (0, 4), 1, (0, 5)
# Executed action: down at state (0, 5)
# (0, 5), 3, (1, 5)
# Executed action: left at state (1, 5)
# (1, 5), 0, (1, 4)
# Executed action: left at state (1, 4)
# (1, 4), 0, (1, 3)
# Executed action: right at state (1, 3)
# (1, 3), 1, (1, 4)
# Executed action: right at state (1, 4)
# (1, 4), 1, (1, 5)
# Executed action: right at state (1, 5)
# (1, 5), 1, (1, 6)
# Executed action: left at state (1, 6)
# (1, 6), 0, (1, 5)
# Executed action: down at state (1, 5)
# (1, 5), 3, (2, 5)
# Executed action: down at state (2, 5)
# (2, 5), 3, (3, 5)
# Executed action: right at state (3, 5)
# (3, 5), 1, (3, 6)
# Executed action: right at state (3, 6)
# (3, 6), 1, (3, 7)
# Executed action: left at state (3, 7)
# (3, 7), 0, (3, 6)
# Executed action: left at state (3, 6)
# (3, 6), 0, (3, 5)
# Executed action: down at state (3, 5)
# (3, 5), 3, (4, 5)
# Executed action: up at state (4, 5)
# (4, 5), 2, (3, 5)
# Episode: 2
# Executed action: left at state (0, 0)
# (0, 0), 0, (0, 0)
# Executed action: right at state (0, 0)
# (0, 0), 1, (0, 1)
# Executed action: left at state (0, 1)
# (0, 1), 0, (0, 0)
# Executed action: right at state (0, 0)
# (0, 0), 1, (0, 1)
# Executed action: down at state (0, 1)
# (0, 1), 3, (1, 1)
# Executed action: left at state (1, 1)
# (1, 1), 0, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: down at state (1, 0)
# (1, 0), 3, (2, 0)
# Executed action: down at state (2, 0)
# (2, 0), 3, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: down at state (3, 0)
# (3, 0), 3, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: right at state (4, 0)
# (4, 0), 1, (4, 1)
# Executed action: up at state (4, 1)
# (4, 1), 2, (3, 1)
# Executed action: right at state (3, 1)
# (3, 1), 1, (3, 2)
# Executed action: left at state (3, 2)
# (3, 2), 0, (3, 1)
# Executed action: left at state (3, 1)
# (3, 1), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: up at state (3, 0)
# (3, 0), 2, (2, 0)
# Executed action: down at state (2, 0)
# (2, 0), 3, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: right at state (3, 0)
# (3, 0), 1, (3, 1)
# Executed action: left at state (3, 1)
# (3, 1), 0, (3, 0)
# Executed action: right at state (3, 0)
# (3, 0), 1, (3, 1)
# Executed action: right at state (3, 1)
# (3, 1), 1, (3, 2)
# Executed action: right at state (3, 2)
# (3, 2), 1, (3, 3)
# Executed action: left at state (3, 3)
# (3, 3), 0, (3, 2)
# Executed action: right at state (3, 2)
# (3, 2), 1, (3, 3)
# Executed action: left at state (3, 3)
# (3, 3), 0, (3, 2)
# Executed action: left at state (3, 2)
# (3, 2), 0, (3, 1)
# Executed action: left at state (3, 1)
# (3, 1), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: right at state (3, 0)
# (3, 0), 1, (3, 1)
# Executed action: down at state (3, 1)
# (3, 1), 3, (4, 1)
# Executed action: left at state (4, 1)
# (4, 1), 0, (4, 0)
# Executed action: up at state (4, 0)
# (4, 0), 2, (3, 0)
# Executed action: right at state (3, 0)
# (3, 0), 1, (3, 1)
# Executed action: left at state (3, 1)
# (3, 1), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: right at state (3, 0)
# (3, 0), 1, (3, 1)
# Executed action: left at state (3, 1)
# (3, 1), 0, (3, 0)
# Executed action: right at state (3, 0)
# (3, 0), 1, (3, 1)
# Executed action: left at state (3, 1)
# (3, 1), 0, (3, 0)
# Executed action: right at state (3, 0)
# (3, 0), 1, (3, 1)
# Executed action: left at state (3, 1)
# (3, 1), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: down at state (3, 0)
# (3, 0), 3, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: right at state (4, 0)
# (4, 0), 1, (4, 1)
# Executed action: right at state (4, 1)
# (4, 1), 1, (4, 2)
# Executed action: left at state (4, 2)
# (4, 2), 0, (4, 1)
# Executed action: left at state (4, 1)
# (4, 1), 0, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: up at state (4, 0)
# (4, 0), 2, (3, 0)
# Executed action: up at state (3, 0)
# (3, 0), 2, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: up at state (2, 0)
# (2, 0), 2, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: up at state (1, 0)
# (1, 0), 2, (0, 0)
# Executed action: left at state (0, 0)
# (0, 0), 0, (0, 0)
# Executed action: left at state (0, 0)
# (0, 0), 0, (0, 0)
# Executed action: left at state (0, 0)
# (0, 0), 0, (0, 0)
# Executed action: down at state (0, 0)
# (0, 0), 3, (1, 0)
# Executed action: down at state (1, 0)
# (1, 0), 3, (2, 0)
# Executed action: up at state (2, 0)
# (2, 0), 2, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: up at state (1, 0)
# (1, 0), 2, (0, 0)
# Executed action: left at state (0, 0)
# (0, 0), 0, (0, 0)
# Executed action: down at state (0, 0)
# (0, 0), 3, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: down at state (1, 0)
# (1, 0), 3, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: down at state (2, 0)
# (2, 0), 3, (3, 0)
# Executed action: down at state (3, 0)
# (3, 0), 3, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: up at state (4, 0)
# (4, 0), 2, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: down at state (3, 0)
# (3, 0), 3, (4, 0)
# Executed action: down at state (4, 0)
# (4, 0), 3, (5, 0)
# Executed action: up at state (5, 0)
# (5, 0), 2, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: down at state (4, 0)
# (4, 0), 3, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: right at state (5, 0)
# (5, 0), 1, (5, 1)
# Executed action: left at state (5, 1)
# (5, 1), 0, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: up at state (5, 0)
# (5, 0), 2, (4, 0)
# Executed action: up at state (4, 0)
# (4, 0), 2, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: up at state (3, 0)
# (3, 0), 2, (2, 0)
# Executed action: down at state (2, 0)
# (2, 0), 3, (3, 0)
# Executed action: down at state (3, 0)
# (3, 0), 3, (4, 0)
# Executed action: up at state (4, 0)
# (4, 0), 2, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: up at state (3, 0)
# (3, 0), 2, (2, 0)
# Executed action: down at state (2, 0)
# (2, 0), 3, (3, 0)
# Executed action: up at state (3, 0)
# (3, 0), 2, (2, 0)
# Executed action: up at state (2, 0)
# (2, 0), 2, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: up at state (1, 0)
# (1, 0), 2, (0, 0)
# Executed action: left at state (0, 0)
# (0, 0), 0, (0, 0)
# Executed action: left at state (0, 0)
# (0, 0), 0, (0, 0)
# Executed action: down at state (0, 0)
# (0, 0), 3, (1, 0)
# Executed action: down at state (1, 0)
# (1, 0), 3, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: up at state (2, 0)
# (2, 0), 2, (1, 0)
# Executed action: right at state (1, 0)
# (1, 0), 1, (1, 1)
# Executed action: left at state (1, 1)
# (1, 1), 0, (1, 0)
# Executed action: up at state (1, 0)
# (1, 0), 2, (0, 0)
# Executed action: right at state (0, 0)
# (0, 0), 1, (0, 1)
# Executed action: left at state (0, 1)
# (0, 1), 0, (0, 0)
# Executed action: down at state (0, 0)
# (0, 0), 3, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: down at state (1, 0)
# (1, 0), 3, (2, 0)
# Executed action: up at state (2, 0)
# (2, 0), 2, (1, 0)
# Executed action: down at state (1, 0)
# (1, 0), 3, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: down at state (2, 0)
# (2, 0), 3, (3, 0)
# Executed action: right at state (3, 0)
# (3, 0), 1, (3, 1)
# Executed action: left at state (3, 1)
# (3, 1), 0, (3, 0)
# Executed action: right at state (3, 0)
# (3, 0), 1, (3, 1)
# Executed action: left at state (3, 1)
# (3, 1), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: right at state (3, 0)
# (3, 0), 1, (3, 1)
# Executed action: down at state (3, 1)
# (3, 1), 3, (4, 1)
# Executed action: left at state (4, 1)
# (4, 1), 0, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: up at state (4, 0)
# (4, 0), 2, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: down at state (3, 0)
# (3, 0), 3, (4, 0)
# Executed action: up at state (4, 0)
# (4, 0), 2, (3, 0)
# Executed action: right at state (3, 0)
# (3, 0), 1, (3, 1)
# Executed action: left at state (3, 1)
# (3, 1), 0, (3, 0)
# Executed action: up at state (3, 0)
# (3, 0), 2, (2, 0)
# Executed action: up at state (2, 0)
# (2, 0), 2, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: down at state (1, 0)
# (1, 0), 3, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: up at state (2, 0)
# (2, 0), 2, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: down at state (1, 0)
# (1, 0), 3, (2, 0)
# Executed action: down at state (2, 0)
# (2, 0), 3, (3, 0)
# Executed action: up at state (3, 0)
# (3, 0), 2, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: down at state (2, 0)
# (2, 0), 3, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: down at state (3, 0)
# (3, 0), 3, (4, 0)
# Executed action: right at state (4, 0)
# (4, 0), 1, (4, 1)
# Executed action: left at state (4, 1)
# (4, 1), 0, (4, 0)
# Executed action: down at state (4, 0)
# (4, 0), 3, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: right at state (5, 0)
# (5, 0), 1, (5, 1)
# Executed action: left at state (5, 1)
# (5, 1), 0, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: down at state (5, 0)
# (5, 0), 3, (6, 0)
# Executed action: left at state (6, 0)
# (6, 0), 0, (6, 0)
# Executed action: left at state (6, 0)
# (6, 0), 0, (6, 0)
# Executed action: down at state (6, 0)
# (6, 0), 3, (7, 0)
# Executed action: up at state (7, 0)
# (7, 0), 2, (6, 0)
# Executed action: right at state (6, 0)
# (6, 0), 1, (6, 1)
# Executed action: right at state (6, 1)
# (6, 1), 1, (6, 2)
# Executed action: up at state (6, 2)
# (6, 2), 2, (5, 2)
# Executed action: left at state (5, 2)
# (5, 2), 0, (5, 1)
# Executed action: left at state (5, 1)
# (5, 1), 0, (5, 0)
# Executed action: up at state (5, 0)
# (5, 0), 2, (4, 0)
# Executed action: up at state (4, 0)
# (4, 0), 2, (3, 0)
# Executed action: right at state (3, 0)
# (3, 0), 1, (3, 1)
# Executed action: down at state (3, 1)
# (3, 1), 3, (4, 1)
# Executed action: left at state (4, 1)
# (4, 1), 0, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: up at state (4, 0)
# (4, 0), 2, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: down at state (3, 0)
# (3, 0), 3, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: down at state (4, 0)
# (4, 0), 3, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: down at state (5, 0)
# (5, 0), 3, (6, 0)
# Executed action: up at state (6, 0)
# (6, 0), 2, (5, 0)
# Executed action: up at state (5, 0)
# (5, 0), 2, (4, 0)
# Executed action: down at state (4, 0)
# (4, 0), 3, (5, 0)
# Executed action: up at state (5, 0)
# (5, 0), 2, (4, 0)
# Executed action: right at state (4, 0)
# (4, 0), 1, (4, 1)
# Executed action: right at state (4, 1)
# (4, 1), 1, (4, 2)
# Executed action: left at state (4, 2)
# (4, 2), 0, (4, 1)
# Executed action: down at state (4, 1)
# (4, 1), 3, (5, 1)
# Executed action: left at state (5, 1)
# (5, 1), 0, (5, 0)
# Executed action: up at state (5, 0)
# (5, 0), 2, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: up at state (4, 0)
# (4, 0), 2, (3, 0)
# Executed action: down at state (3, 0)
# (3, 0), 3, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: down at state (4, 0)
# (4, 0), 3, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: up at state (5, 0)
# (5, 0), 2, (4, 0)
# Executed action: down at state (4, 0)
# (4, 0), 3, (5, 0)
# Executed action: right at state (5, 0)
# (5, 0), 1, (5, 1)
# Executed action: right at state (5, 1)
# (5, 1), 1, (5, 2)
# Executed action: left at state (5, 2)
# (5, 2), 0, (5, 1)
# Executed action: left at state (5, 1)
# (5, 1), 0, (5, 0)
# Executed action: down at state (5, 0)
# (5, 0), 3, (6, 0)
# Executed action: up at state (6, 0)
# (6, 0), 2, (5, 0)
# Executed action: down at state (5, 0)
# (5, 0), 3, (6, 0)
# Executed action: left at state (6, 0)
# (6, 0), 0, (6, 0)
# Executed action: left at state (6, 0)
# (6, 0), 0, (6, 0)
# Executed action: up at state (6, 0)
# (6, 0), 2, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: right at state (5, 0)
# (5, 0), 1, (5, 1)
# Executed action: down at state (5, 1)
# (5, 1), 3, (6, 1)
# Executed action: left at state (6, 1)
# (6, 1), 0, (6, 0)
# Executed action: left at state (6, 0)
# (6, 0), 0, (6, 0)
# Executed action: left at state (6, 0)
# (6, 0), 0, (6, 0)
# Executed action: up at state (6, 0)
# (6, 0), 2, (5, 0)
# Executed action: down at state (5, 0)
# (5, 0), 3, (6, 0)
# Executed action: left at state (6, 0)
# (6, 0), 0, (6, 0)
# Executed action: left at state (6, 0)
# (6, 0), 0, (6, 0)
# Executed action: down at state (6, 0)
# (6, 0), 3, (7, 0)
# Executed action: right at state (7, 0)
# (7, 0), 1, (7, 1)
# Executed action: down at state (7, 1)
# (7, 1), 3, (8, 1)
# Executed action: up at state (8, 1)
# (8, 1), 2, (7, 1)
# Executed action: left at state (7, 1)
# (7, 1), 0, (7, 0)
# Executed action: left at state (7, 0)
# (7, 0), 0, (7, 0)
# Executed action: right at state (7, 0)
# (7, 0), 1, (7, 1)
# Executed action: left at state (7, 1)
# (7, 1), 0, (7, 0)
# Executed action: down at state (7, 0)
# (7, 0), 3, (8, 0)
# Executed action: left at state (8, 0)
# (8, 0), 0, (8, 0)
# Executed action: left at state (8, 0)
# (8, 0), 0, (8, 0)
# Executed action: left at state (8, 0)
# (8, 0), 0, (8, 0)
# Executed action: left at state (8, 0)
# (8, 0), 0, (8, 0)
# Executed action: right at state (8, 0)
# (8, 0), 1, (8, 1)
# Executed action: left at state (8, 1)
# (8, 1), 0, (8, 0)
# Executed action: left at state (8, 0)
# (8, 0), 0, (8, 0)
# Executed action: left at state (8, 0)
# (8, 0), 0, (8, 0)
# Executed action: up at state (8, 0)
# (8, 0), 2, (7, 0)
# Executed action: down at state (7, 0)
# (7, 0), 3, (8, 0)
# Executed action: down at state (8, 0)
# (8, 0), 3, (9, 0)
# Executed action: right at state (9, 0)
# (9, 0), 1, (9, 1)
# Executed action: left at state (9, 1)
# (9, 1), 0, (9, 0)
# Executed action: left at state (9, 0)
# (9, 0), 0, (9, 0)
# Executed action: right at state (9, 0)
# (9, 0), 1, (9, 1)
# Executed action: up at state (9, 1)
# (9, 1), 2, (8, 1)
# Executed action: left at state (8, 1)
# (8, 1), 0, (8, 0)
# Executed action: up at state (8, 0)
# (8, 0), 2, (7, 0)
# Executed action: up at state (7, 0)
# (7, 0), 2, (6, 0)
# Executed action: right at state (6, 0)
# (6, 0), 1, (6, 1)
# Executed action: left at state (6, 1)
# (6, 1), 0, (6, 0)
# Executed action: up at state (6, 0)
# (6, 0), 2, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: up at state (5, 0)
# (5, 0), 2, (4, 0)
# Executed action: down at state (4, 0)
# (4, 0), 3, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: down at state (5, 0)
# (5, 0), 3, (6, 0)
# Executed action: left at state (6, 0)
# (6, 0), 0, (6, 0)
# Executed action: left at state (6, 0)
# (6, 0), 0, (6, 0)
# Executed action: down at state (6, 0)
# (6, 0), 3, (7, 0)
# Executed action: up at state (7, 0)
# (7, 0), 2, (6, 0)
# Executed action: left at state (6, 0)
# (6, 0), 0, (6, 0)
# Executed action: right at state (6, 0)
# (6, 0), 1, (6, 1)
# Executed action: left at state (6, 1)
# (6, 1), 0, (6, 0)
# Executed action: right at state (6, 0)
# (6, 0), 1, (6, 1)
# Executed action: left at state (6, 1)
# (6, 1), 0, (6, 0)
# Executed action: left at state (6, 0)
# (6, 0), 0, (6, 0)
# Executed action: left at state (6, 0)
# (6, 0), 0, (6, 0)
# Executed action: up at state (6, 0)
# (6, 0), 2, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: up at state (5, 0)
# (5, 0), 2, (4, 0)
# Executed action: right at state (4, 0)
# (4, 0), 1, (4, 1)
# Executed action: left at state (4, 1)
# (4, 1), 0, (4, 0)
# Executed action: down at state (4, 0)
# (4, 0), 3, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: right at state (5, 0)
# (5, 0), 1, (5, 1)
# Executed action: down at state (5, 1)
# (5, 1), 3, (6, 1)
# Executed action: left at state (6, 1)
# (6, 1), 0, (6, 0)
# Executed action: left at state (6, 0)
# (6, 0), 0, (6, 0)
# Executed action: left at state (6, 0)
# (6, 0), 0, (6, 0)
# Executed action: down at state (6, 0)
# (6, 0), 3, (7, 0)
# Executed action: left at state (7, 0)
# (7, 0), 0, (7, 0)
# Executed action: right at state (7, 0)
# (7, 0), 1, (7, 1)
# Executed action: left at state (7, 1)
# (7, 1), 0, (7, 0)
# Executed action: up at state (7, 0)
# (7, 0), 2, (6, 0)
# Executed action: right at state (6, 0)
# (6, 0), 1, (6, 1)
# Executed action: down at state (6, 1)
# (6, 1), 3, (7, 1)
# Executed action: left at state (7, 1)
# (7, 1), 0, (7, 0)
# Executed action: left at state (7, 0)
# (7, 0), 0, (7, 0)
# Executed action: left at state (7, 0)
# (7, 0), 0, (7, 0)
# Executed action: left at state (7, 0)
# (7, 0), 0, (7, 0)
# Executed action: left at state (7, 0)
# (7, 0), 0, (7, 0)
# Executed action: down at state (7, 0)
# (7, 0), 3, (8, 0)
# Executed action: left at state (8, 0)
# (8, 0), 0, (8, 0)
# Executed action: up at state (8, 0)
# (8, 0), 2, (7, 0)
# Executed action: left at state (7, 0)
# (7, 0), 0, (7, 0)
# Executed action: left at state (7, 0)
# (7, 0), 0, (7, 0)
# Executed action: left at state (7, 0)
# (7, 0), 0, (7, 0)
# Executed action: left at state (7, 0)
# (7, 0), 0, (7, 0)
# Executed action: down at state (7, 0)
# (7, 0), 3, (8, 0)
# Executed action: left at state (8, 0)
# (8, 0), 0, (8, 0)
# Executed action: left at state (8, 0)
# (8, 0), 0, (8, 0)
# Executed action: up at state (8, 0)
# (8, 0), 2, (7, 0)
# Executed action: left at state (7, 0)
# (7, 0), 0, (7, 0)
# Executed action: left at state (7, 0)
# (7, 0), 0, (7, 0)
# Executed action: down at state (7, 0)
# (7, 0), 3, (8, 0)
# Executed action: left at state (8, 0)
# (8, 0), 0, (8, 0)
# Executed action: down at state (8, 0)
# (8, 0), 3, (9, 0)
# Executed action: left at state (9, 0)
# (9, 0), 0, (9, 0)
# Executed action: up at state (9, 0)
# (9, 0), 2, (8, 0)
# Executed action: up at state (8, 0)
# (8, 0), 2, (7, 0)
# Executed action: down at state (7, 0)
# (7, 0), 3, (8, 0)
# Executed action: down at state (8, 0)
# (8, 0), 3, (9, 0)
# Executed action: left at state (9, 0)
# (9, 0), 0, (9, 0)
# Executed action: left at state (9, 0)
# (9, 0), 0, (9, 0)
# Executed action: left at state (9, 0)
# (9, 0), 0, (9, 0)
# Executed action: left at state (9, 0)
# (9, 0), 0, (9, 0)
# Executed action: right at state (9, 0)
# (9, 0), 1, (9, 1)
# Executed action: left at state (9, 1)
# (9, 1), 0, (9, 0)
# Executed action: up at state (9, 0)
# (9, 0), 2, (8, 0)
# Executed action: right at state (8, 0)
# (8, 0), 1, (8, 1)
# Executed action: left at state (8, 1)
# (8, 1), 0, (8, 0)
# Executed action: up at state (8, 0)
# (8, 0), 2, (7, 0)
# Executed action: left at state (7, 0)
# (7, 0), 0, (7, 0)
# Executed action: left at state (7, 0)
# (7, 0), 0, (7, 0)
# Executed action: up at state (7, 0)
# (7, 0), 2, (6, 0)
# Executed action: left at state (6, 0)
# (6, 0), 0, (6, 0)
# Executed action: left at state (6, 0)
# (6, 0), 0, (6, 0)
# Executed action: right at state (6, 0)
# (6, 0), 1, (6, 1)
# Executed action: up at state (6, 1)
# (6, 1), 2, (5, 1)
# Executed action: right at state (5, 1)
# (5, 1), 1, (5, 2)
# Executed action: left at state (5, 2)
# (5, 2), 0, (5, 1)
# Executed action: left at state (5, 1)
# (5, 1), 0, (5, 0)
# Executed action: up at state (5, 0)
# (5, 0), 2, (4, 0)
# Executed action: right at state (4, 0)
# (4, 0), 1, (4, 1)
# Executed action: left at state (4, 1)
# (4, 1), 0, (4, 0)
# Executed action: up at state (4, 0)
# (4, 0), 2, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: up at state (3, 0)
# (3, 0), 2, (2, 0)
# Executed action: down at state (2, 0)
# (2, 0), 3, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: up at state (3, 0)
# (3, 0), 2, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: down at state (2, 0)
# (2, 0), 3, (3, 0)
# Executed action: right at state (3, 0)
# (3, 0), 1, (3, 1)
# Executed action: left at state (3, 1)
# (3, 1), 0, (3, 0)
# Executed action: down at state (3, 0)
# (3, 0), 3, (4, 0)
# Executed action: right at state (4, 0)
# (4, 0), 1, (4, 1)
# Executed action: left at state (4, 1)
# (4, 1), 0, (4, 0)
# Executed action: up at state (4, 0)
# (4, 0), 2, (3, 0)
# Executed action: right at state (3, 0)
# (3, 0), 1, (3, 1)
# Executed action: left at state (3, 1)
# (3, 1), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: up at state (3, 0)
# (3, 0), 2, (2, 0)
# Executed action: down at state (2, 0)
# (2, 0), 3, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: down at state (3, 0)
# (3, 0), 3, (4, 0)
# Executed action: right at state (4, 0)
# (4, 0), 1, (4, 1)
# Executed action: right at state (4, 1)
# (4, 1), 1, (4, 2)
# Executed action: up at state (4, 2)
# (4, 2), 2, (3, 2)
# Executed action: right at state (3, 2)
# (3, 2), 1, (3, 3)
# Executed action: left at state (3, 3)
# (3, 3), 0, (3, 2)
# Executed action: left at state (3, 2)
# (3, 2), 0, (3, 1)
# Executed action: right at state (3, 1)
# (3, 1), 1, (3, 2)
# Executed action: left at state (3, 2)
# (3, 2), 0, (3, 1)
# Executed action: left at state (3, 1)
# (3, 1), 0, (3, 0)
# Executed action: up at state (3, 0)
# (3, 0), 2, (2, 0)
# Executed action: down at state (2, 0)
# (2, 0), 3, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: down at state (3, 0)
# (3, 0), 3, (4, 0)
# Executed action: down at state (4, 0)
# (4, 0), 3, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: up at state (5, 0)
# (5, 0), 2, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: right at state (4, 0)
# (4, 0), 1, (4, 1)
# Executed action: left at state (4, 1)
# (4, 1), 0, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: down at state (4, 0)
# (4, 0), 3, (5, 0)
# Executed action: up at state (5, 0)
# (5, 0), 2, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: down at state (4, 0)
# (4, 0), 3, (5, 0)
# Executed action: up at state (5, 0)
# (5, 0), 2, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: up at state (4, 0)
# (4, 0), 2, (3, 0)
# Executed action: up at state (3, 0)
# (3, 0), 2, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: up at state (2, 0)
# (2, 0), 2, (1, 0)
# Executed action: down at state (1, 0)
# (1, 0), 3, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: up at state (2, 0)
# (2, 0), 2, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: up at state (1, 0)
# (1, 0), 2, (0, 0)
# Executed action: right at state (0, 0)
# (0, 0), 1, (0, 1)
# Executed action: right at state (0, 1)
# (0, 1), 1, (0, 2)
# Executed action: left at state (0, 2)
# (0, 2), 0, (0, 1)
# Executed action: left at state (0, 1)
# (0, 1), 0, (0, 0)
# Executed action: down at state (0, 0)
# (0, 0), 3, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: down at state (1, 0)
# (1, 0), 3, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: up at state (2, 0)
# (2, 0), 2, (1, 0)
# Executed action: down at state (1, 0)
# (1, 0), 3, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: down at state (2, 0)
# (2, 0), 3, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: up at state (3, 0)
# (3, 0), 2, (2, 0)
# Executed action: down at state (2, 0)
# (2, 0), 3, (3, 0)
# Executed action: right at state (3, 0)
# (3, 0), 1, (3, 1)
# Executed action: left at state (3, 1)
# (3, 1), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: down at state (3, 0)
# (3, 0), 3, (4, 0)
# Executed action: down at state (4, 0)
# (4, 0), 3, (5, 0)
# Executed action: up at state (5, 0)
# (5, 0), 2, (4, 0)
# Executed action: up at state (4, 0)
# (4, 0), 2, (3, 0)
# Executed action: right at state (3, 0)
# (3, 0), 1, (3, 1)
# Executed action: left at state (3, 1)
# (3, 1), 0, (3, 0)
# Executed action: right at state (3, 0)
# (3, 0), 1, (3, 1)
# Executed action: down at state (3, 1)
# (3, 1), 3, (4, 1)
# Executed action: left at state (4, 1)
# (4, 1), 0, (4, 0)
# Executed action: up at state (4, 0)
# (4, 0), 2, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: right at state (3, 0)
# (3, 0), 1, (3, 1)
# Executed action: left at state (3, 1)
# (3, 1), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# ...
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: up at state (4, 0)
# (4, 0), 2, (3, 0)
# Executed action: right at state (3, 0)
# (3, 0), 1, (3, 1)
# Executed action: left at state (3, 1)
# (3, 1), 0, (3, 0)
# Executed action: right at state (3, 0)
# (3, 0), 1, (3, 1)
# Executed action: down at state (3, 1)
# (3, 1), 3, (4, 1)
# Executed action: left at state (4, 1)
# (4, 1), 0, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: right at state (4, 0)
# (4, 0), 1, (4, 1)
# Executed action: left at state (4, 1)
# (4, 1), 0, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: down at state (4, 0)
# (4, 0), 3, (5, 0)
# Executed action: up at state (5, 0)
# (5, 0), 2, (4, 0)
# Executed action: right at state (4, 0)
# (4, 0), 1, (4, 1)
# Executed action: right at state (4, 1)
# (4, 1), 1, (4, 2)
# Executed action: up at state (4, 2)
# (4, 2), 2, (3, 2)
# Executed action: left at state (3, 2)
# (3, 2), 0, (3, 1)
# Executed action: left at state (3, 1)
# (3, 1), 0, (3, 0)
# Executed action: left at state (3, 0)
# (3, 0), 0, (3, 0)
# Executed action: down at state (3, 0)
# (3, 0), 3, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: down at state (4, 0)
# (4, 0), 3, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: up at state (5, 0)
# (5, 0), 2, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: down at state (4, 0)
# (4, 0), 3, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: down at state (5, 0)
# (5, 0), 3, (6, 0)
# Executed action: down at state (6, 0)
# (6, 0), 3, (7, 0)
# Executed action: right at state (7, 0)
# (7, 0), 1, (7, 1)
# Executed action: down at state (7, 1)
# (7, 1), 3, (8, 1)
# Executed action: left at state (8, 1)
# (8, 1), 0, (8, 0)
# Executed action: left at state (8, 0)
# (8, 0), 0, (8, 0)
# Executed action: up at state (8, 0)
# (8, 0), 2, (7, 0)
# Executed action: right at state (7, 0)
# (7, 0), 1, (7, 1)
# Executed action: left at state (7, 1)
# (7, 1), 0, (7, 0)
# Executed action: left at state (7, 0)
# (7, 0), 0, (7, 0)
# Executed action: up at state (7, 0)
# (7, 0), 2, (6, 0)
# Executed action: down at state (6, 0)
# (6, 0), 3, (7, 0)
# Executed action: left at state (7, 0)
# (7, 0), 0, (7, 0)
# Executed action: up at state (7, 0)
# (7, 0), 2, (6, 0)
# Executed action: left at state (6, 0)
# (6, 0), 0, (6, 0)
# Executed action: left at state (6, 0)
# (6, 0), 0, (6, 0)
# Executed action: down at state (6, 0)
# (6, 0), 3, (7, 0)
# Executed action: left at state (7, 0)
# (7, 0), 0, (7, 0)
# Executed action: left at state (7, 0)
# (7, 0), 0, (7, 0)
# Executed action: left at state (7, 0)
# (7, 0), 0, (7, 0)
# Executed action: down at state (7, 0)
# (7, 0), 3, (8, 0)
# Executed action: left at state (8, 0)
# (8, 0), 0, (8, 0)
# Executed action: up at state (8, 0)
# (8, 0), 2, (7, 0)
# Executed action: left at state (7, 0)
# (7, 0), 0, (7, 0)
# Executed action: up at state (7, 0)
# (7, 0), 2, (6, 0)
# Executed action: left at state (6, 0)
# (6, 0), 0, (6, 0)
# Executed action: left at state (6, 0)
# (6, 0), 0, (6, 0)
# Executed action: left at state (6, 0)
# (6, 0), 0, (6, 0)
# Executed action: right at state (6, 0)
# (6, 0), 1, (6, 1)
# Executed action: right at state (6, 1)
# (6, 1), 1, (6, 2)
# Executed action: down at state (6, 2)
# (6, 2), 3, (7, 2)
# Executed action: left at state (7, 2)
# (7, 2), 0, (7, 1)
# Executed action: left at state (7, 1)
# (7, 1), 0, (7, 0)
# Executed action: left at state (7, 0)
# (7, 0), 0, (7, 0)
# Executed action: down at state (7, 0)
# (7, 0), 3, (8, 0)
# Executed action: right at state (8, 0)
# (8, 0), 1, (8, 1)
# Executed action: left at state (8, 1)
# (8, 1), 0, (8, 0)
# Executed action: up at state (8, 0)
# (8, 0), 2, (7, 0)
# Executed action: left at state (7, 0)
# (7, 0), 0, (7, 0)
# Executed action: up at state (7, 0)
# (7, 0), 2, (6, 0)
# Executed action: up at state (6, 0)
# (6, 0), 2, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: down at state (5, 0)
# (5, 0), 3, (6, 0)
# Executed action: down at state (6, 0)
# (6, 0), 3, (7, 0)
# Executed action: left at state (7, 0)
# (7, 0), 0, (7, 0)
# Executed action: up at state (7, 0)
# (7, 0), 2, (6, 0)
# Executed action: left at state (6, 0)
# (6, 0), 0, (6, 0)
# Executed action: left at state (6, 0)
# (6, 0), 0, (6, 0)
# Executed action: up at state (6, 0)
# (6, 0), 2, (5, 0)
# Executed action: down at state (5, 0)
# (5, 0), 3, (6, 0)
# Executed action: right at state (6, 0)
# (6, 0), 1, (6, 1)
# Executed action: up at state (6, 1)
# (6, 1), 2, (5, 1)
# Executed action: left at state (5, 1)
# (5, 1), 0, (5, 0)
# Executed action: down at state (5, 0)
# (5, 0), 3, (6, 0)
# Executed action: left at state (6, 0)
# (6, 0), 0, (6, 0)
# Executed action: up at state (6, 0)
# (6, 0), 2, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: left at state (5, 0)
# (5, 0), 0, (5, 0)
# Executed action: up at state (5, 0)
# (5, 0), 2, (4, 0)
# Executed action: up at state (4, 0)
# (4, 0), 2, (3, 0)
# Executed action: down at state (3, 0)
# (3, 0), 3, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: left at state (4, 0)
# (4, 0), 0, (4, 0)
# Executed action: up at state (4, 0)
# (4, 0), 2, (3, 0)
# Executed action: up at state (3, 0)
# (3, 0), 2, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: left at state (2, 0)
# (2, 0), 0, (2, 0)
# Executed action: up at state (2, 0)
# (2, 0), 2, (1, 0)
# Executed action: up at state (1, 0)
# (1, 0), 2, (0, 0)
# Executed action: down at state (0, 0)
# (0, 0), 3, (1, 0)
# Executed action: right at state (1, 0)
# (1, 0), 1, (1, 1)
# Executed action: left at state (1, 1)
# (1, 1), 0, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: up at state (1, 0)
# (1, 0), 2, (0, 0)
# Executed action: down at state (0, 0)
# (0, 0), 3, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: up at state (1, 0)
# (1, 0), 2, (0, 0)
# Executed action: left at state (0, 0)
# (0, 0), 0, (0, 0)
# Executed action: left at state (0, 0)
# (0, 0), 0, (0, 0)
# Executed action: right at state (0, 0)
# (0, 0), 1, (0, 1)
# Executed action: right at state (0, 1)
# (0, 1), 1, (0, 2)
# Executed action: left at state (0, 2)
# (0, 2), 0, (0, 1)
# Executed action: right at state (0, 1)
# (0, 1), 1, (0, 2)
# Executed action: left at state (0, 2)
# (0, 2), 0, (0, 1)
# Executed action: left at state (0, 1)
# (0, 1), 0, (0, 0)
# Executed action: left at state (0, 0)
# (0, 0), 0, (0, 0)
# Executed action: left at state (0, 0)
# (0, 0), 0, (0, 0)
# Executed action: down at state (0, 0)
# (0, 0), 3, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: right at state (1, 0)
# (1, 0), 1, (1, 1)
# Executed action: left at state (1, 1)
# (1, 1), 0, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: left at state (1, 0)
# (1, 0), 0, (1, 0)
# Executed action: down at state (1, 0)
# (1, 0), 3, (2, 0)
# Executed action: down at state (2, 0)
# (2, 0), 3, (3, 0)
# Executed action: right at state (3, 0)
# (3, 0), 1, (3, 1)
# Executed action: right at state (3, 1)
# (3, 1), 1, (3, 2)
# Executed action: down at state (3, 2)
# (3, 2), 3, (4, 2)
# Executed action: right at state (4, 2)
# (4, 2), 1, (4, 3)
# Executed action: left at state (4, 3)
# (4, 3), 0, (4, 2)
# Executed action: right at state (4, 2)
# (4, 2), 1, (4, 3)
# Executed action: down at state (4, 3)
# (4, 3), 3, (5, 3)
# Executed action: left at state (5, 3)
# (5, 3), 0, (5, 2)
# Executed action: left at state (5, 2)
# (5, 2), 0, (5, 1)
# Executed action: left at state (5, 1)
# (5, 1), 0, (5, 0)
# Executed action: right at state (5, 0)
# (5, 0), 1, (5, 1)
# Executed action: down at state (5, 1)
# (5, 1), 3, (6, 1)
# Executed action: left at state (6, 1)
# (6, 1), 0, (6, 0)
# Executed action: down at state (6, 0)
# (6, 0), 3, (7, 0)
# Executed action: left at state (7, 0)
# (7, 0), 0, (7, 0)
# Executed action: down at state (7, 0)
# (7, 0), 3, (8, 0)
# Executed action: left at state (8, 0)
# (8, 0), 0, (8, 0)
# Executed action: left at state (8, 0)
# (8, 0), 0, (8, 0)
# Executed action: down at state (8, 0)
# (8, 0), 3, (9, 0)
# Executed action: right at state (9, 0)
# (9, 0), 1, (9, 1)
# Executed action: left at state (9, 1)
# (9, 1), 0, (9, 0)
# Executed action: right at state (9, 0)
# (9, 0), 1, (9, 1)
# Executed action: left at state (9, 1)
# (9, 1), 0, (9, 0)
# Executed action: left at state (9, 0)
# (9, 0), 0, (9, 0)
# Executed action: left at state (9, 0)
# (9, 0), 0, (9, 0)
# Executed action: up at state (9, 0)
# (9, 0), 2, (8, 0)
# Executed action: up at state (8, 0)
# (8, 0), 2, (7, 0)
# Executed action: left at state (7, 0)
# (7, 0), 0, (7, 0)
# Executed action: left at state (7, 0)
# (7, 0), 0, (7, 0)
# Executed action: left at state (7, 0)
# (7, 0), 0, (7, 0)
# Executed action: down at state (7, 0)
# (7, 0), 3, (8, 0)
# Executed action: left at state (8, 0)
# (8, 0), 0, (8, 0)
# Executed action: left at state (8, 0)
# (8, 0), 0, (8, 0)
# Executed action: right at state (8, 0)
# (8, 0), 1, (8, 1)
# Executed action: up at state (8, 1)
# (8, 1), 2, (7, 1)
# Executed action: down at state (7, 1)
# (7, 1), 3, (8, 1)
# Executed action: left at state (8, 1)
# (8, 1), 0, (8, 0)
# Executed action: left at state (8, 0)
# (8, 0), 0, (8, 0)
# Executed action: left at state (8, 0)
# (8, 0), 0, (8, 0)
# Executed action: up at state (8, 0)
# (8, 0), 2, (7, 0)
# Executed action: right at state (7, 0)
# (7, 0), 1, (7, 1)
# Executed action: down at state (7, 1)
# (7, 1), 3, (8, 1)
# Executed action: left at state (8, 1)
# (8, 1), 0, (8, 0)
# Executed action: left at state (8, 0)
# (8, 0), 0, (8, 0)
# Executed action: down at state (8, 0)
# (8, 0), 3, (9, 0)
# Executed action: left at state (9, 0)
# (9, 0), 0, (9, 0)
# Executed action: up at state (9, 0)
# (9, 0), 2, (8, 0)
# Executed action: down at state (8, 0)
# (8, 0), 3, (9, 0)
# Executed action: up at state (9, 0)
# (9, 0), 2, (8, 0)
# Executed action: left at state (8, 0)
# (8, 0), 0, (8, 0)
# Executed action: up at state (8, 0)
# (8, 0), 2, (7, 0)
# Executed action: right at state (7, 0)
# (7, 0), 1, (7, 1)
# Executed action: left at state (7, 1)
# (7, 1), 0, (7, 0)
# Executed action: left at state (7, 0)
# (7, 0), 0, (7, 0)
# Executed action: left at state (7, 0)
# (7, 0), 0, (7, 0)
# Executed action: left at state (7, 0)
# (7, 0), 0, (7, 0)
# Executed action: left at state (7, 0)
# (7, 0), 0, (7, 0)
# Executed action: right at state (7, 0)
# (7, 0), 1, (7, 1)
# Executed action: left at state (7, 1)
# (7, 1), 0, (7, 0)
# Executed action: left at state (7, 0)
# (7, 0), 0, (7, 0)
# Executed action: down at state (7, 0)
# (7, 0), 3, (8, 0)
# Executed action: left at state (8, 0)
# (8, 0), 0, (8, 0)
# Executed action: down at state (8, 0)
# (8, 0), 3, (9, 0)
# Executed action: left at state (9, 0)
# (9, 0), 0, (9, 0)
# Executed action: left at state (9, 0)
# (9, 0), 0, (9, 0)
# Executed action: up at state (9, 0)
# (9, 0), 2, (8, 0)
# Executed action: down at state (8, 0)
# (8, 0), 3, (9, 0)
# Executed action: left at state (9, 0)
# (9, 0), 0, (9, 0)
# Executed action: left at state (9, 0)
# (9, 0), 0, (9, 0)
# Executed action: right at state (9, 0)
# (9, 0), 1, (9, 1)
# Executed action: left at state (9, 1)
# (9, 1), 0, (9, 0)
# Executed action: left at state (9, 0)
# (9, 0), 0, (9, 0)
# Executed action: up at state (9, 0)
# (9, 0), 2, (8, 0)
# Executed action: down at state (8, 0)
# (8, 0), 3, (9, 0)
# Executed action: up at state (9, 0)
# (9, 0), 2, (8, 0)
# Executed action: right at state (8, 0)
# (8, 0), 1, (8, 1)
# Executed action: right at state (8, 1)
# (8, 1), 1, (8, 2)
# Executed action: down at state (8, 2)
# (8, 2), 3, (9, 2)
# Executed action: right at state (9, 2)
# (9, 2), 1, (9, 3)
# Executed action: up at state (9, 3)
# (9, 3), 2, (8, 3)
# Executed action: down at state (8, 3)
# (8, 3), 3, (9, 3)
# Executed action: right at state (9, 3)
# (9, 3), 1, (9, 4)
# Executed action: left at state (9, 4)
# (9, 4), 0, (9, 3)
# Executed action: right at state (9, 3)
# (9, 3), 1, (9, 4)
# Executed action: right at state (9, 4)
# (9, 4), 1, (9, 5)
# Executed action: up at state (9, 5)
# (9, 5), 2, (8, 5)
# Executed action: right at state (8, 5)
# (8, 5), 1, (8, 6)
# Executed action: left at state (8, 6)
# (8, 6), 0, (8, 5)
# Executed action: up at state (8, 5)
# (8, 5), 2, (7, 5)
# Executed action: left at state (7, 5)
# (7, 5), 0, (7, 5)
# {(0, 0): array([0., 0., 0., 0.]), (0, 1): array([0., 0., 0., 0.]), (0, 2): array([0., 0., 0., 0.]), (0, 3): array([0., 0., 0., 0.]), (0, 4): array([0., 0., 0., 0.]), (0, 5): array([0., 0., 0., 0.]), (0, 6): array([0., 0., 0., 0.]), (0, 7): array([0., 0., 0., 0.]), (0, 8): array([0., 0., 0., 0.]), (0, 9): array([0., 0., 0., 0.]), (1, 0): array([0., 0., 0., 0.]), (1, 1): array([0., 0., 0., 0.]), (1, 2): array([0., 0., 0., 0.]), (1, 3): array([0., 0., 0., 0.]), (1, 4): array([0., 0., 0., 0.]), (1, 5): array([0., 0., 0., 0.]), (1, 6): array([0., 0., 0., 0.]), (1, 7): array([0., 0., 0., 0.]), (1, 8): array([0., 0., 0., 0.]), (1, 9): array([0., 0., 0., 0.]), (2, 0): array([0., 0., 0., 0.]), (2, 1): array([0., 0., 0., 0.]), (2, 2): array([0., 0., 0., 0.]), (2, 3): array([0., 0., 0., 0.]), (2, 4): array([0., 0., 0., 0.]), (2, 5): array([0., 0., 0., 0.]), (2, 6): array([0., 0., 0., 0.]), (2, 7): array([0., 0., 0., 0.]), (2, 8): array([0., 0., 0., 0.]), (2, 9): array([0., 0., 0., 0.]), (3, 0): array([0., 0., 0., 0.]), (3, 1): array([0., 0., 0., 0.]), (3, 2): array([0., 0., 0., 0.]), (3, 3): array([0., 0., 0., 0.]), (3, 4): array([0., 0., 0., 0.]), (3, 5): array([0., 0., 0., 0.]), (3, 6): array([0., 0., 0., 0.]), (3, 7): array([0., 0., 0., 0.]), (3, 8): array([0., 0., 0., 0.]), (3, 9): array([0., 0., 0., 0.]), (4, 0): array([0., 0., 0., 0.]), (4, 1): array([0., 0., 0., 0.]), (4, 2): array([0., 0., 0., 0.]), (4, 3): array([0., 0., 0., 0.]), (4, 4): array([0., 0., 0., 0.]), (4, 5): array([ 0. ,  0. , -0.1,  0. ]), (4, 6): array([0., 0., 0., 0.]), (4, 7): array([0., 0., 0., 0.]), (4, 8): array([0., 0., 0., 0.]), (4, 9): array([0., 0., 0., 0.]), (5, 0): array([0., 0., 0., 0.]), (5, 1): array([0., 0., 0., 0.]), (5, 2): array([0., 0., 0., 0.]), (5, 3): array([0., 0., 0., 0.]), (5, 4): array([0., 0., 0., 0.]), (5, 5): array([0., 0., 0., 0.]), (5, 6): array([0., 0., 0., 0.]), (5, 7): array([0., 0., 0., 0.]), (5, 8): array([0., 0., 0., 0.]), (5, 9): array([0., 0., 0., 0.]), (6, 0): array([0., 0., 0., 0.]), (6, 1): array([0., 0., 0., 0.]), (6, 2): array([0., 0., 0., 0.]), (6, 3): array([0., 0., 0., 0.]), (6, 4): array([0., 0., 0., 0.]), (6, 5): array([0., 0., 0., 0.]), (6, 6): array([0., 0., 0., 0.]), (6, 7): array([0., 0., 0., 0.]), (6, 8): array([0., 0., 0., 0.]), (6, 9): array([0., 0., 0., 0.]), (7, 0): array([0., 0., 0., 0.]), (7, 1): array([0., 0., 0., 0.]), (7, 2): array([0., 0., 0., 0.]), (7, 3): array([0., 0., 0., 0.]), (7, 4): array([0., 0., 0., 0.]), (7, 5): array([-0.1,  0. ,  0. ,  0. ]), (7, 6): array([0., 0., 0., 0.]), (7, 7): array([0., 0., 0., 0.]), (7, 8): array([0., 0., 0., 0.]), (7, 9): array([0., 0., 0., 0.]), (8, 0): array([0., 0., 0., 0.]), (8, 1): array([0., 0., 0., 0.]), (8, 2): array([0., 0., 0., 0.]), (8, 3): array([0., 0., 0., 0.]), (8, 4): array([0., 0., 0., 0.]), (8, 5): array([0., 0., 0., 0.]), (8, 6): array([0., 0., 0., 0.]), (8, 7): array([0., 0., 0., 0.]), (8, 8): array([0., 0., 0., 0.]), (8, 9): array([0., 0., 0., 0.]), (9, 0): array([0., 0., 0., 0.]), (9, 1): array([0., 0., 0., 0.]), (9, 2): array([0., 0., 0., 0.]), (9, 3): array([0., 0., 0., 0.]), (9, 4): array([0., 0., 0., 0.]), (9, 5): array([0., 0., 0., 0.]), (9, 6): array([0., 0., 0., 0.]), (9, 7): array([0., 0., 0., 0.]), (9, 8): array([0., 0., 0., 0.]), (9, 9): array([0., 0., 0., 0.])}

# %%
np.random.choice([7, 9, 10])
# Out:
# 9
